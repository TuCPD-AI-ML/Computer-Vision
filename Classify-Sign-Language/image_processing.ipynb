# %%
# %cd /content/drive/MyDrive/DeepLearning/sign_language_mnist/data/alpha_add2
# !unzip /content/drive/MyDrive/DeepLearning/sign_language_mnist/data/alpha_add2/alpha_add2.zip
# Out:
# /content/drive/MyDrive/DeepLearning/sign_language_mnist/data/alpha_add2
# Archive:  /content/drive/MyDrive/DeepLearning/sign_language_mnist/data/alpha_add2/alpha_add2.zip
#   inflating: m/imageA_1702116643.9124415.png
#   inflating: m/imageA_1702116644.5005043.png
#   inflating: m/imageA_1702116644.8046868.png
#   inflating: m/imageA_1702116646.3484719.png
#   inflating: m/imageA_1702116646.6554441.png
#   inflating: m/imageA_1702116646.963529.png
#   inflating: m/imageA_1702116647.2930622.png
#   inflating: m/imageA_1702116647.6114476.png
#   inflating: m/imageA_1702116647.9310617.png
#   inflating: m/imageA_1702116648.238414.png
#   inflating: m/imageA_1702116648.5522244.png
#   inflating: m/imageA_1702116648.8592691.png
#   inflating: m/imageA_1702116649.1692848.png
#   inflating: m/imageA_1702116649.4888132.png
#   inflating: m/imageA_1702116649.7921891.png
#   inflating: m/imageA_1702116650.1140277.png
#   inflating: m/imageA_1702116650.4243553.png
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import os

# %%
folder = '/content/drive/MyDrive/DeepLearning/sign_language_mnist/data/alpha_add2'
for subfolder in os.listdir(folder):
    subfolder_path = os.path.join(folder, subfolder)

    if os.path.isdir(subfolder_path):
        for filename in os.listdir(subfolder_path):
            if filename.endswith('.png'):
                img_path = os.path.join(subfolder_path, filename)
                img = cv2.imread(img_path)
                gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                blur = cv2.GaussianBlur(gray, (3, 3), 0)
                img_resized = cv2.resize(blur, (28, 28))
                norm_img = cv2.normalize(img_resized, None, 0, 255, cv2.NORM_MINMAX)
                output_path = os.path.join(subfolder_path, f'{filename}')
                cv2.imwrite(output_path, norm_img)

# %%
img = cv2.imread('/content/drive/MyDrive/DeepLearning/sign_language_mnist/code/imageA_1701767219.8916.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (3, 3), 0)
img_resized = cv2.resize(blur, (28, 28))
normalized_image = cv2.normalize(img_resized, None, 0, 255, cv2.NORM_MINMAX)
plt.imshow(normalized_image, cmap='gray');
