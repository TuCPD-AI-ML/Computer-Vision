# %%
# !python yolov7/detect.py --weights best.pt --conf 0.4 --source 0 --img-size 640
# Out:
# Namespace(weights=['best.pt'], source='0', img_size=640, conf_thres=0.4, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# Fusing layers...
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 1/1: 0...  success (640x480 at 30.00 FPS).
#
# 0: Done. (1067.2ms) Inference, (9.0ms) NMS
# 0: Done. (1033.3ms) Inference, (0.0ms) NMS
# 0: Done. (952.1ms) Inference, (0.0ms) NMS
# 0: Done. (916.1ms) Inference, (0.0ms) NMS
# 0: Done. (918.0ms) Inference, (0.0ms) NMS
# 0: 1 hand, Done. (899.8ms) Inference, (9.0ms) NMS
# 0: Done. (912.1ms) Inference, (0.0ms) NMS
# 0: 2 hands, Done. (918.2ms) Inference, (1.0ms) NMS
# 0: Done. (897.4ms) Inference, (0.0ms) NMS
# 0: Done. (910.2ms) Inference, (0.0ms) NMS
# 0: Done. (905.7ms) Inference, (0.0ms) NMS
# ...
